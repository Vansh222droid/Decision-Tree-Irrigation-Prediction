# %%
# Importing Required librareis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
# Importing the data
df = pd.read_csv("irrigation_prediction.csv")
df.head()
# Out:
#   Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0      Clay     6.14          36.48            0.42                     2.17
# 1      Silt     6.41          50.56            0.38                     0.23
# 2     Sandy     7.71          40.07            1.09                     2.18
# 3      Clay     5.96          12.75            1.56                     0.40
# 4      Clay     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
#   Crop_Type Crop_Growth_Stage  Season Irrigation_Type Water_Source  \
# ...

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Soil_Type                10000 non-null  object
#  1   Soil_pH                  10000 non-null  float64
#  2   Soil_Moisture            10000 non-null  float64
#  3   Organic_Carbon           10000 non-null  float64
#  4   Electrical_Conductivity  10000 non-null  float64
#  5   Temperature_C            10000 non-null  float64
#  6   Humidity                 10000 non-null  float64
#  7   Rainfall_mm              10000 non-null  float64
#  8   Sunlight_Hours           10000 non-null  float64
#  9   Wind_Speed_kmh           10000 non-null  float64
#  10  Crop_Type                10000 non-null  object
#  11  Crop_Growth_Stage        10000 non-null  object
#  12  Season                   10000 non-null  object
# ...

# %%
df.describe()
# Out:
#             Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# count  10000.000000   10000.000000    10000.000000             10000.000000
# mean       6.487857      36.969207        0.944731                 1.791963
# std        0.979963      16.430845        0.372406                 0.984202
# min        4.800000       8.000000        0.300000                 0.100000
# 25%        5.640000      22.860000        0.620000                 0.940000
# 50%        6.470000      37.240000        0.950000                 1.780000
# 75%        7.350000      50.940000        1.260000                 2.650000
# max        8.200000      65.000000        1.600000                 3.500000
#
#        Temperature_C      Humidity   Rainfall_mm  Sunlight_Hours  \
# count   10000.000000  10000.000000  10000.000000    10000.000000
# mean       26.991423     60.080339   1252.499420        7.518538
# std         8.664074     20.187973    715.582201        2.016077
# ...

# %%
num_df = df.select_dtypes(include = 'number')
num_df.columns
# Out:
# Index(['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity',
#        'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours',
#        'Wind_Speed_kmh', 'Field_Area_hectare', 'Previous_Irrigation_mm'],
#       dtype='object')

# %%
# sns.pairplot(df, hue = 'Irrigation_Need', palette = 'rainbow')
# plt.show()

# %%
obj_df = df.select_dtypes(include = 'O')
print(obj_df.shape)
obj_df.head()
# Out:
# (10000, 9)
#   Soil_Type Crop_Type Crop_Growth_Stage  Season Irrigation_Type Water_Source  \
# 0      Clay     Wheat        Vegetative    Rabi         Rainfed    Reservoir
# 1      Silt     Maize         Flowering    Zaid           Canal  Groundwater
# 2     Sandy    Cotton           Harvest    Rabi            Drip    Reservoir
# 3      Clay     Wheat            Sowing  Kharif           Canal    Reservoir
# 4      Clay    Cotton            Sowing    Zaid           Canal        River
#
#   Mulching_Used   Region Irrigation_Need
# 0           Yes    South             Low
# 1           Yes  Central          Medium
# 2           Yes    South             Low
# 3           Yes    North          Medium
# 4            No    South          Medium

# %%
cat_cols = obj_df.columns.tolist()
print(cat_cols)
# Out:
# ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region', 'Irrigation_Need']

# %%
fig, ax = plt.subplots(9,1, figsize = (5,15))
for i in cat_cols:
    sns.countplot(df[i],ax = ax[cat_cols.index(i)])
    plt.tight_layout()
plt.show()

# %%
X = df.drop("Irrigation_Need", axis = 1)
y = df['Irrigation_Need']

# %%
X.head()
# Out:
#   Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0      Clay     6.14          36.48            0.42                     2.17
# 1      Silt     6.41          50.56            0.38                     0.23
# 2     Sandy     7.71          40.07            1.09                     2.18
# 3      Clay     5.96          12.75            1.56                     0.40
# 4      Clay     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
#   Crop_Type Crop_Growth_Stage  Season Irrigation_Type Water_Source  \
# ...

# %%
y.head()
# Out:
# 0       Low
# 1    Medium
# 2       Low
# 3    Medium
# 4    Medium
# Name: Irrigation_Need, dtype: object

# %%
print(cat_cols)
# Out:
# ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region', 'Irrigation_Need']

# %%
encoder = LabelEncoder()
for col in cat_cols[:-1]:
    X[col] = encoder.fit_transform(X[col])

# %%
X.head()
# Out:
#    Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0          0     6.14          36.48            0.42                     2.17
# 1          3     6.41          50.56            0.38                     0.23
# 2          2     7.71          40.07            1.09                     2.18
# 3          0     5.96          12.75            1.56                     0.40
# 4          0     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 11, test_size = 0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7000, 19) (3000, 19) (7000,) (3000,)

# %%
dtc = DecisionTreeClassifier(criterion='entropy',splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0, monotonic_cst=None)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = dtc.predict(X_test)
print(y_pred[90:100])

# %%
y_test[90:100]

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         High       0.99      0.97      0.98        99
#          Low       1.00      1.00      1.00      1781
#       Medium       0.99      1.00      0.99      1120
#
#     accuracy                           1.00      3000
#    macro avg       0.99      0.99      0.99      3000
# weighted avg       1.00      1.00      1.00      3000
